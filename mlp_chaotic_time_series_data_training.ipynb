# %% [markdown]
# <a href="https://colab.research.google.com/github/dannywillowliu-uchi/mlp_asset_pricing/blob/main/mlp_chaotic_time_series_data_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.integrate import solve_ivp
import os
import torch
from torch.utils.data import DataLoader, Dataset
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %% [markdown]
# lorenz func data gen
#
# outputs csvs with format time, Var where time is an integer, and Var is the value of given Var at t

# %%
def lorenz(t, state, sigma=10, beta=8/3, rho=28):
    x, y, z = state
    dxdt = sigma * (y - x)
    dydt = x * (rho - z) - y
    dzdt = x * y - beta * z
    return [dxdt, dydt, dzdt]

# Initial conditions
state0 = [1.0, 1.0, 1.0]
time_span = (0, 10000)


# Generate integer time points
#time_eval = np.linspace(time_span[0], time_span[1], 10000) #Original Line
time_eval = np.arange(time_span[0], time_span[1] + 1, dtype=int)  # New Line

output_dir = 'lorenz_output'
if not os.path.exists(output_dir):
       os.makedirs(output_dir)


for i in range(-2000,2000):

    #Scrambles x y and z starting conditions to generate a new system
    state0[i % 3] == i

    # Solve the system
    sol = solve_ivp(lorenz, time_span, state0, t_eval=time_eval)

    #Save the time series data of the x y and z axes as individual csvs
    dfx = pd.DataFrame({'Time': sol.t, 'X': sol.y[0]})
    dfx.to_csv("lorenz_output_x" + str(i) + ".csv", index=False)
    print("Data saved to lorenz_output_x" + str(i) + ".csv")

    dfy = pd.DataFrame({'Time': sol.t, 'Y': sol.y[1]})
    dfy.to_csv("lorenz_output_y " + str(i) + ".csv", index=False)
    print("Data saved to lorenz_output_y " + str(i) + ".csv")

    dfz = pd.DataFrame({'Time': sol.t, 'Z': sol.y[2]})
    dfz.to_csv("lorenz_output_z" + str(i) + ".csv", index=False)
    print("Data saved to lorenz_output_z" + str(i) + ".csv")
# Out:
# Data saved to lorenz_output_x-2000.csv
# Data saved to lorenz_output_y -2000.csv
# Data saved to lorenz_output_z-2000.csv
# Data saved to lorenz_output_x-1999.csv
# Data saved to lorenz_output_y -1999.csv
# Data saved to lorenz_output_z-1999.csv
# Data saved to lorenz_output_x-1998.csv
# Data saved to lorenz_output_y -1998.csv
# Data saved to lorenz_output_z-1998.csv
# Data saved to lorenz_output_x-1997.csv
# Data saved to lorenz_output_y -1997.csv
# Data saved to lorenz_output_z-1997.csv
# Data saved to lorenz_output_x-1996.csv
# Data saved to lorenz_output_y -1996.csv
# Data saved to lorenz_output_z-1996.csv
# Data saved to lorenz_output_x-1995.csv
# Data saved to lorenz_output_y -1995.csv
# Data saved to lorenz_output_z-1995.csv
# Data saved to lorenz_output_x-1994.csv
# Data saved to lorenz_output_y -1994.csv
# Data saved to lorenz_output_z-1994.csv
# Data saved to lorenz_output_x-1993.csv
# Data saved to lorenz_output_y -1993.csv
# Data saved to lorenz_output_z-1993.csv
# Data saved to lorenz_output_x-1992.csv
# Data saved to lorenz_output_y -1992.csv
# Data saved to lorenz_output_z-1992.csv
# Data saved to lorenz_output_x-1991.csv
# Data saved to lorenz_output_y -1991.csv
# Data saved to lorenz_output_z-1991.csv
# Data saved to lorenz_output_x-1990.csv
# Data saved to lorenz_output_y -1990.csv
# Data saved to lorenz_output_z-1990.csv
# Data saved to lorenz_output_x-1989.csv
# Data saved to lorenz_output_y -1989.csv
# Data saved to lorenz_output_z-1989.csv
# Data saved to lorenz_output_x-1988.csv
# Data saved to lorenz_output_y -1988.csv
# Data saved to lorenz_output_z-1988.csv
# Data saved to lorenz_output_x-1987.csv
# Data saved to lorenz_output_y -1987.csv
# Data saved to lorenz_output_z-1987.csv
# Data saved to lorenz_output_x-1986.csv
# Data saved to lorenz_output_y -1986.csv
# Data saved to lorenz_output_z-1986.csv
# Data saved to lorenz_output_x-1985.csv
# Data saved to lorenz_output_y -1985.csv
# Data saved to lorenz_output_z-1985.csv
# Data saved to lorenz_output_x-1984.csv
# Data saved to lorenz_output_y -1984.csv
# Data saved to lorenz_output_z-1984.csv
# Data saved to lorenz_output_x-1983.csv
# Data saved to lorenz_output_y -1983.csv
# Data saved to lorenz_output_z-1983.csv
# Data saved to lorenz_output_x-1982.csv
# Data saved to lorenz_output_y -1982.csv
# Data saved to lorenz_output_z-1982.csv
# Data saved to lorenz_output_x-1981.csv
# Data saved to lorenz_output_y -1981.csv
# Data saved to lorenz_output_z-1981.csv
# Data saved to lorenz_output_x-1980.csv
# Data saved to lorenz_output_y -1980.csv
# Data saved to lorenz_output_z-1980.csv
# Data saved to lorenz_output_x-1979.csv
# Data saved to lorenz_output_y -1979.csv
# Data saved to lorenz_output_z-1979.csv
# Data saved to lorenz_output_x-1978.csv
# Data saved to lorenz_output_y -1978.csv
# Data saved to lorenz_output_z-1978.csv
# Data saved to lorenz_output_x-1977.csv
# Data saved to lorenz_output_y -1977.csv
# Data saved to lorenz_output_z-1977.csv
# Data saved to lorenz_output_x-1976.csv
# Data saved to lorenz_output_y -1976.csv
# Data saved to lorenz_output_z-1976.csv
# Data saved to lorenz_output_x-1975.csv
# Data saved to lorenz_output_y -1975.csv
# Data saved to lorenz_output_z-1975.csv
# Data saved to lorenz_output_x-1974.csv
# Data saved to lorenz_output_y -1974.csv
# Data saved to lorenz_output_z-1974.csv
# Data saved to lorenz_output_x-1973.csv
# Data saved to lorenz_output_y -1973.csv
# Data saved to lorenz_output_z-1973.csv
# Data saved to lorenz_output_x-1972.csv
# Data saved to lorenz_output_y -1972.csv
# Data saved to lorenz_output_z-1972.csv
# Data saved to lorenz_output_x-1971.csv
# Data saved to lorenz_output_y -1971.csv
# Data saved to lorenz_output_z-1971.csv
# Data saved to lorenz_output_x-1970.csv
# Data saved to lorenz_output_y -1970.csv
# Data saved to lorenz_output_z-1970.csv
# Data saved to lorenz_output_x-1969.csv
# Data saved to lorenz_output_y -1969.csv
# Data saved to lorenz_output_z-1969.csv
# Data saved to lorenz_output_x-1968.csv
# Data saved to lorenz_output_y -1968.csv
# Data saved to lorenz_output_z-1968.csv
# Data saved to lorenz_output_x-1967.csv
# Data saved to lorenz_output_y -1967.csv
# Data saved to lorenz_output_z-1967.csv
# Data saved to lorenz_output_x-1966.csv
# Data saved to lorenz_output_y -1966.csv
# Data saved to lorenz_output_z-1966.csv
# Data saved to lorenz_output_x-1965.csv
# Data saved to lorenz_output_y -1965.csv
# Data saved to lorenz_output_z-1965.csv
# Data saved to lorenz_output_x-1964.csv
# Data saved to lorenz_output_y -1964.csv
# Data saved to lorenz_output_z-1964.csv
# Data saved to lorenz_output_x-1963.csv
# Data saved to lorenz_output_y -1963.csv
# Data saved to lorenz_output_z-1963.csv
# Data saved to lorenz_output_x-1962.csv
# Data saved to lorenz_output_y -1962.csv
# Data saved to lorenz_output_z-1962.csv
# Data saved to lorenz_output_x-1961.csv
# Data saved to lorenz_output_y -1961.csv
# Data saved to lorenz_output_z-1961.csv
# Data saved to lorenz_output_x-1960.csv
# Data saved to lorenz_output_y -1960.csv
# Data saved to lorenz_output_z-1960.csv
# Data saved to lorenz_output_x-1959.csv
# Data saved to lorenz_output_y -1959.csv
# Data saved to lorenz_output_z-1959.csv
# Data saved to lorenz_output_x-1958.csv
# Data saved to lorenz_output_y -1958.csv
# Data saved to lorenz_output_z-1958.csv
# Data saved to lorenz_output_x-1957.csv
# Data saved to lorenz_output_y -1957.csv
# Data saved to lorenz_output_z-1957.csv
# Data saved to lorenz_output_x-1956.csv
# Data saved to lorenz_output_y -1956.csv
# Data saved to lorenz_output_z-1956.csv
# Data saved to lorenz_output_x-1955.csv
# Data saved to lorenz_output_y -1955.csv
# Data saved to lorenz_output_z-1955.csv
# Data saved to lorenz_output_x-1954.csv
# Data saved to lorenz_output_y -1954.csv
# Data saved to lorenz_output_z-1954.csv
# Data saved to lorenz_output_x-1953.csv
# Data saved to lorenz_output_y -1953.csv
# Data saved to lorenz_output_z-1953.csv
# Data saved to lorenz_output_x-1952.csv
# Data saved to lorenz_output_y -1952.csv
# Data saved to lorenz_output_z-1952.csv
# Data saved to lorenz_output_x-1951.csv
# Data saved to lorenz_output_y -1951.csv
# Data saved to lorenz_output_z-1951.csv
# Data saved to lorenz_output_x-1950.csv
# Data saved to lorenz_output_y -1950.csv
# Data saved to lorenz_output_z-1950.csv
# Data saved to lorenz_output_x-1949.csv
# Data saved to lorenz_output_y -1949.csv
# Data saved to lorenz_output_z-1949.csv
# Data saved to lorenz_output_x-1948.csv
# Data saved to lorenz_output_y -1948.csv
# Data saved to lorenz_output_z-1948.csv
# Data saved to lorenz_output_x-1947.csv
# Data saved to lorenz_output_y -1947.csv
# Data saved to lorenz_output_z-1947.csv
# Data saved to lorenz_output_x-1946.csv
# Data saved to lorenz_output_y -1946.csv
# Data saved to lorenz_output_z-1946.csv
# Data saved to lorenz_output_x-1945.csv
# Data saved to lorenz_output_y -1945.csv
# Data saved to lorenz_output_z-1945.csv
# Data saved to lorenz_output_x-1944.csv
# Data saved to lorenz_output_y -1944.csv
# Data saved to lorenz_output_z-1944.csv
# Data saved to lorenz_output_x-1943.csv
# Data saved to lorenz_output_y -1943.csv
# Data saved to lorenz_output_z-1943.csv
# Data saved to lorenz_output_x-1942.csv
# Data saved to lorenz_output_y -1942.csv
# Data saved to lorenz_output_z-1942.csv
# Data saved to lorenz_output_x-1941.csv
# Data saved to lorenz_output_y -1941.csv
# Data saved to lorenz_output_z-1941.csv
# Data saved to lorenz_output_x-1940.csv
# Data saved to lorenz_output_y -1940.csv
# Data saved to lorenz_output_z-1940.csv
# Data saved to lorenz_output_x-1939.csv
# Data saved to lorenz_output_y -1939.csv
# Data saved to lorenz_output_z-1939.csv
# Data saved to lorenz_output_x-1938.csv
# Data saved to lorenz_output_y -1938.csv
# Data saved to lorenz_output_z-1938.csv
# Data saved to lorenz_output_x-1937.csv
# Data saved to lorenz_output_y -1937.csv
# Data saved to lorenz_output_z-1937.csv
# Data saved to lorenz_output_x-1936.csv
# Data saved to lorenz_output_y -1936.csv
# Data saved to lorenz_output_z-1936.csv
# Data saved to lorenz_output_x-1935.csv
# Data saved to lorenz_output_y -1935.csv
# Data saved to lorenz_output_z-1935.csv
# Data saved to lorenz_output_x-1934.csv
# Data saved to lorenz_output_y -1934.csv
# Data saved to lorenz_output_z-1934.csv
# Data saved to lorenz_output_x-1933.csv
# Data saved to lorenz_output_y -1933.csv
# Data saved to lorenz_output_z-1933.csv
# Data saved to lorenz_output_x-1932.csv
# Data saved to lorenz_output_y -1932.csv
# Data saved to lorenz_output_z-1932.csv
# Data saved to lorenz_output_x-1931.csv
# Data saved to lorenz_output_y -1931.csv
# Data saved to lorenz_output_z-1931.csv
# Data saved to lorenz_output_x-1930.csv
# Data saved to lorenz_output_y -1930.csv
# Data saved to lorenz_output_z-1930.csv
# Data saved to lorenz_output_x-1929.csv
# Data saved to lorenz_output_y -1929.csv
# Data saved to lorenz_output_z-1929.csv
# Data saved to lorenz_output_x-1928.csv
# Data saved to lorenz_output_y -1928.csv
# Data saved to lorenz_output_z-1928.csv
# Data saved to lorenz_output_x-1927.csv
# Data saved to lorenz_output_y -1927.csv
# Data saved to lorenz_output_z-1927.csv
# Data saved to lorenz_output_x-1926.csv
# Data saved to lorenz_output_y -1926.csv
# Data saved to lorenz_output_z-1926.csv
# Data saved to lorenz_output_x-1925.csv
# Data saved to lorenz_output_y -1925.csv
# Data saved to lorenz_output_z-1925.csv
# Data saved to lorenz_output_x-1924.csv
# Data saved to lorenz_output_y -1924.csv
# Data saved to lorenz_output_z-1924.csv
# Data saved to lorenz_output_x-1923.csv
# Data saved to lorenz_output_y -1923.csv
# Data saved to lorenz_output_z-1923.csv
# Data saved to lorenz_output_x-1922.csv
# Data saved to lorenz_output_y -1922.csv
# Data saved to lorenz_output_z-1922.csv
# Data saved to lorenz_output_x-1921.csv
# Data saved to lorenz_output_y -1921.csv
# Data saved to lorenz_output_z-1921.csv
# Data saved to lorenz_output_x-1920.csv
# Data saved to lorenz_output_y -1920.csv
# Data saved to lorenz_output_z-1920.csv
# Data saved to lorenz_output_x-1919.csv
# Data saved to lorenz_output_y -1919.csv
# Data saved to lorenz_output_z-1919.csv
# Data saved to lorenz_output_x-1918.csv
# Data saved to lorenz_output_y -1918.csv
# Data saved to lorenz_output_z-1918.csv
# Data saved to lorenz_output_x-1917.csv
# Data saved to lorenz_output_y -1917.csv
# Data saved to lorenz_output_z-1917.csv
# Data saved to lorenz_output_x-1916.csv
# Data saved to lorenz_output_y -1916.csv
# Data saved to lorenz_output_z-1916.csv
# Data saved to lorenz_output_x-1915.csv
# Data saved to lorenz_output_y -1915.csv
# Data saved to lorenz_output_z-1915.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e24082c19d03> in <cell line: 0>()
#      26
#      27     # Solve the system
# ---> 28     sol = solve_ivp(lorenz, time_span, state0, t_eval=time_eval)
#      29
#      30     #Save the time series data of the x y and z axes as individual csvs
#
# /usr/local/lib/python3.11/dist-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     653     status = None
#     654     while status is None:
# --> 655         message = solver.step()
#     656
#     657         if solver.status == 'finished':
#
# /usr/local/lib/python3.11/dist-packages/scipy/integrate/_ivp/base.py in step(self)
#     195         else:
#     196             t = self.t
# --> 197             success, message = self._step_impl()
#     198
#     199             if not success:
#
# /usr/local/lib/python3.11/dist-packages/scipy/integrate/_ivp/rk.py in _step_impl(self)
#     142             h_abs = np.abs(h)
#     143
# --> 144             y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                                    self.B, self.C, self.K)
#     146             scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#
# /usr/local/lib/python3.11/dist-packages/scipy/integrate/_ivp/rk.py in rk_step(fun, t, y, f, h, A, B, C, K)
#      62     for s, (a, c) in enumerate(zip(A[1:], C[1:]), start=1):
#      63         dy = np.dot(K[:s].T, a[:s]) * h
# ---> 64         K[s] = fun(t + c * h, y + dy)
#      65
#      66     y_new = y + h * np.dot(K[:-1].T, B)
#
# /usr/local/lib/python3.11/dist-packages/scipy/integrate/_ivp/base.py in fun(t, y)
#     152         def fun(t, y):
#     153             self.nfev += 1
# --> 154             return self.fun_single(t, y)
#     155
#     156         self.fun = fun
#
# /usr/local/lib/python3.11/dist-packages/scipy/integrate/_ivp/base.py in fun_wrapped(t, y)
#      21
#      22     def fun_wrapped(t, y):
# ---> 23         return np.asarray(fun(t, y), dtype=dtype)
#      24
#      25     return fun_wrapped, y0
#
# KeyboardInterrupt:

# %%
import pandas as pd
import glob
import os

def combine_csv_files(directory, output_prefix):
    """Combines CSV files in a directory based on their prefixes (x, y, z)."""

    for prefix in ['x', 'y', 'z']:
        all_files = glob.glob(os.path.join(directory, f'lorenz_output_{prefix}*.csv'))
        if not all_files:
            print(f"No files found with prefix '{prefix}' in the specified directory.")
            continue

        combined_df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
        output_filename = os.path.join(directory, f'{output_prefix}_{prefix}.csv')
        combined_df.to_csv(output_filename, index=False)
        print(f"Combined '{prefix}' files into '{output_filename}'")

# Example usage:
combine_csv_files('/content', 'combined_lorenz')
# Out:
# Combined 'x' files into '/content/combined_lorenz_x.csv'
# Combined 'y' files into '/content/combined_lorenz_y.csv'
# Combined 'z' files into '/content/combined_lorenz_z.csv'

# %%
class TimeSeriesDataset(Dataset):
    def __init__(self, data, sequence_length):
        self.data = data
        self.sequence_length = sequence_length

    def __len__(self):
        return len(self.data) - self.sequence_length  # Changed here

    def __getitem__(self, index):
        x = self.data[index:index + self.sequence_length]  # Input: Past sequence_length values
        y = self.data[index + self.sequence_length]  # Target: The next value after the sequence
        return x, y


# Define the MLP model
class MLP(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):  # Changed input parameters
        super(MLP, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_size, hidden_size),  # Input layer with input_size features
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),  # Hidden layer with hidden_size features
            nn.ReLU(),
            nn.Linear(hidden_size, output_size)   # Output layer with output_size features
        )

    def forward(self, x):
        return self.network(x)


# Training function (remains the same)
def train_model(model, dataloader, criterion, optimizer, num_epochs):
    for epoch in range(num_epochs):
        for data, targets in dataloader:
            # Forward pass
            outputs = model(data).squeeze(1)  # Squeeze the output tensor along dimension 1
            loss = criterion(outputs, targets)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

# %% [markdown]
# # Loading Data

# %%
dfx = pd.read_csv("/content/combined_lorenz_x.csv")  # Load data for 'x'
data = torch.tensor(dfx['X'].values, dtype=torch.float32)
targets = torch.randn(100, 1)  # 100 targets
sequence_length = 5
# Hyperparameters
hidden_size = 50
output_size = 1
num_epochs = 10
batch_size = 10
learning_rate = 0.1
sequence_length = 20  # Length of the input sequence for time-series prediction
# Dataset and DataLoader
dataset = TimeSeriesDataset(data,sequence_length)  # Only pass data here
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Model, criterion, and optimizer
model = MLP(sequence_length, hidden_size, 1)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
for batch_idx, (data, targets) in enumerate(dataloader):
    print(f"Batch {batch_idx}:")
    print("Data:", data)
    print("Targets:", targets)
    break  # Stop after the first batch to avoid printing too much
# Out:
# Batch 0:
# Data: tensor([[  1.4848,  -5.5948,  15.1942,  -0.7985,  -3.5905, -14.2395,  10.3584,
#           -2.8155,  -5.6088,   7.3627,   0.0449,   5.0145,  10.4340,   4.3222,
#           13.9815,   1.3342,   1.5896, -11.4910,  -3.1208,   7.3257],
#         [ -3.7724,  -2.0804,  -7.9953,  12.3973,  -0.1363,  -4.7809, -14.1353,
#          -10.6034,   4.8519,  13.0290,   0.4423,   2.5061, -11.9648,   5.3521,
#            1.4090,  -0.6608,  11.9647,   3.7855,  12.3164,   3.2048],
#         [  1.3814,  -4.4924,  11.5419,  -3.3724,  -0.6259,  10.6752,   3.7907,
#            1.9571, -13.7015, -10.7009,   2.7392,   5.0507,  -7.8353,  -0.3934,
#            6.0352,   8.9186,   2.3807,  -0.6856,  11.7947,   4.4602],
#         [ -0.3739,   6.3835,   8.2596,   2.5054,  -0.8390,  11.8106,   4.4774,
#           12.8295,   2.1067,   0.3487, -10.2886,  -4.5894, -11.3459,  -3.3849,
#           -0.6471,  10.7844,   3.7206,   1.7140, -13.4442,  -5.1892],
#         [-11.1507,  -5.6543, -10.1902,  -5.3974, -10.6669,  -1.6505,   4.5500,
#          -12.5558, -11.1780,   5.6456,  10.3295,   1.1435,  -6.4368, -11.2808,
#            3.7081,   6.2490,  10.1528,  -4.0131,  -6.5261, -15.9324],
#         [ 12.6016,  -6.0191,   5.8064,  11.3475,  -0.1219,   0.6772, -11.6498,
#           -3.2908,  -3.9960,  15.2028,  -2.0521,  -2.6913, -11.1085,  11.9885,
#           -1.3062,   5.9017, -13.9730,   2.8255,   1.8178, -13.8983],
#         [  2.5630,  -2.8480, -12.8015, -16.8867,   3.3855,  12.7482,  11.0816,
#           -2.0963,   1.9308, -11.5930,  -2.6786,  -6.8302,   9.0879,  16.7570,
#           -5.6348, -10.5275,  -5.6142,  -9.9637,  -3.0634,  -9.4893],
#         [ 10.7053,  -0.4627,   4.9407,  10.9189,   2.4999,   4.0649,  -9.4474,
#           -0.4880,   5.5116,  10.0505,   1.8015,  -4.1372,  11.0294,  -0.2054,
#            2.4879, -14.5024, -14.5142,   4.6111,  12.6567,   2.9314],
#         [  6.1290,  -7.2257,   0.5812,  -6.7310, -16.0753,   1.5253,  -3.8417,
#           -9.1095,   4.4061,   0.4439,  -8.6912,  -5.2740,  -2.8064,   8.9450,
#           -5.0298,   1.4373,  -4.2362,  11.0890,  -0.2026,   0.6033],
#         [ -6.1047, -11.2446,  -0.2771,   3.6263, -14.6128,   2.5402,   2.5541,
#           11.7136,  11.5016,  -4.4228, -12.0880,  -2.9535,  -1.0824,  12.7016,
#            2.5022,  -2.1242,  10.8949,  -7.5839,  -0.6637,   5.5948]])
# Targets: tensor([  9.4376,  -1.8265,  12.8804,   0.1747,   1.9025,  -1.7395,   6.2960,
#           8.1914, -11.3814,  -6.5674])

# %% [markdown]
# # training

# %%
train_model(model, dataloader, criterion, optimizer, num_epochs)
